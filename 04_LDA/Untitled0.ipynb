# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd 
import pickle 
import seaborn as sns
import numpy as np

# %%
from collections import Counter
from matplotlib import pyplot as plt

# %%
def get_processed data(origin_df, start_month, end_month):
  query = data[(data.month >= start_month)& (data.month <= end_month)]

    q1 = query[['comment',' emotion', 'month']].dropna()
    q1.columns = ['comment',' emotion', 'month']
    q2 = query[['comment',' emotion', 'month']].dropna()    
    q2.columns = ['comment',' emotion', 'month']

    q = q1.append(q2)
    q.index = range(len(q))

    q['preprocess'] = q.Reviews.apply(lambda text : " ".join(parser.morphs(text)))
    cnt = Counter(word for line in q.preprocess for word in line.split())
    
    return q, cnt]
# Out:
#   File "<ipython-input-10-3c764b30c1d5>", line 1
#     def get_processed data(origin_df, start_month, end_month):
#                          ^
# SyntaxError: invalid syntax

# %% [markdown]
# 토큰으로 쪼개기

# %%
data = pd.read_csv('/content/drive/Shareddrives/선형대수학/주제분석/DTW+클러스터링/감정분류/감정_생활문화8.csv',encoding='UTF=8-sig')
data['month']=8
data.head()
# Out:
#                                              comment emotion  month
# 0             이게 자영업자의 현실이지...자기 월급도 못가져가는 자영업자 엄창많음      슬픔      8
# 1                       좌빨영화를 돈주고 보는 정신나간 사람도 있나요? ㅋ      놀람      8
# 2                                  내가 제일 싫어하는 제벌 한사람      중립      8
# 3  만취운전 2번에 검사사칭, 형보수지, 4명 자살시킨 놈도 대통령 후보, 국회의원, ...      혐오      8
# 4                         뽕쟁이 주제에 옥중 웹툰 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ      행복      8

# %%
# 클러스터링 결과 나오면
# Out:
#                                                 comment emotion  month
# 0                이게 자영업자의 현실이지...자기 월급도 못가져가는 자영업자 엄창많음      슬픔      8
# 1                          좌빨영화를 돈주고 보는 정신나간 사람도 있나요? ㅋ      놀람      8
# 2                                     내가 제일 싫어하는 제벌 한사람      중립      8
# 3     만취운전 2번에 검사사칭, 형보수지, 4명 자살시킨 놈도 대통령 후보, 국회의원, ...      혐오      8
# 4                            뽕쟁이 주제에 옥중 웹툰 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ      행복      8
# ...                                                 ...     ...    ...
# 4995  얼마나 시간이 지났을까? 고요한 강 저편에서 별안간 첨벙첨벙 소리가 들렸다. 개가 ...      놀람      8
# 4996  이럴수록 독거노인, 지하층에 사는 사람들… 그리고 어려운 환경에 있는 사람들이 무사...      슬픔      8
# 4997    현재의 시대상이 잘 녹아져 있어서 재미있게 잘 읽었습니다.\n이승연 작가님 화이팅!!      행복      8
# 4998  그니까 짭새들한테 수사를 다 넘긴다고  조폭  재벌 정치 목사 땡중 사학재단 등등 ...      혐오      8
# 4999               오늘 보고왔는데 잼나긴한데 이중간첩인지 뭔지 아직도 아리송 ㅋㅋㅋ      혐오      8
#
# [5000 rows x 3 columns]
